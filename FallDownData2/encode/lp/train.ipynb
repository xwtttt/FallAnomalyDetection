# %%
import os
import tensorflow as tf
from tensorflow import keras
os.environ['TF_CPP_MIN_LOG_LEVEL'] = "3"
import numpy as np
import json
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix   #copy

# %%
data = np.load('lp.npz')       #mark final.npz
label = data['y']
Bigdata = data['X']
Bigdata[np.isnan(Bigdata)] = 0.
# Bigdata = Bigdata[:,:,1:]
results = {}
results['acc'] = []
results['auc'] = []
results['confMat'] = []  #add
fold = 0
label[label < 5] = 0
label[label==5] = 1
y = label
index=np.arange(Bigdata.shape[0])
np.random.shuffle(index)
y=y[index]
Bigdata=Bigdata[index]
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=22)

# %%
for train, test in kfold.split(np.zeros(len(y)), y):
    print("run fold:{0}".format(fold))
    train_x, train_y = Bigdata[train], y[train]
    test_x, test_y = Bigdata[test], y[test]
    #train_y, test_y = tf.one_hot(train_y, depth=6).numpy(), tf.one_hot(test_y, depth=6).numpy()
    model = tf.keras.Sequential([
    keras.layers.Masking(mask_value=0., input_shape=(500, 7)), 
    keras.layers.Bidirectional(keras.layers.LSTM(256, return_sequences=True), input_shape=(500, 7)),
    keras.layers.Bidirectional(keras.layers.LSTM(128)),
    keras.layers.Dense(units=64, activation='relu'),
    keras.layers.Dense(units=1, activation='sigmoid')
    ])

    model.compile(optimizer='adam', loss=keras.losses.BinaryCrossentropy(from_logits=False), metrics=['accuracy','AUC'])
    TensorBoard_callback = keras.callbacks.TensorBoard('logs_without_timestamp/' + str(fold) +"/" , histogram_freq=1)
    EarlyStopping_callback = keras.callbacks.EarlyStopping(patience=5)
    checkpoint_callback = keras.callbacks.ModelCheckpoint('checkpoint_without_timestamp/fold_' + str(fold) +"/" , save_best_only=True, save_weights_only=True)
    
    model.fit(x=train_x, y=train_y, batch_size=64, epochs=30, validation_split=0.2, callbacks=[TensorBoard_callback, EarlyStopping_callback, checkpoint_callback], verbose=2)

    #1
    y_pred = model.predict(test_x)
    roc = roc_auc_score(test_y, y_pred)
    y_pred[y_pred >= 0.5 ] =1
    y_pred[y_pred < 0.5] = 0
    acc = accuracy_score(test_y, y_pred)
    confMat = confusion_matrix(test_y, y_pred).astype(str)
    #acc = accuracy_score(np.argmax(test_y, axis=-1), np.argmax(y_pred, axis=-1))
    print("In the fold {0}: acc {1}, roc {2}".format(fold, acc, roc))
    results['acc'].append(acc)
    results['auc'].append(roc)
    confMat = [list(A)for A in confMat]
    results['confMat'].append(confMat)
    fold +=1
    #1

with open('auc_acc_without_timestamp.txt','a') as f:
    f.write(json.dumps(results))
# Out:
# run fold:0
# Train on 220 samples, validate on 56 samples
# Epoch 1/30
# 220/220 - 28s - loss: 0.4174 - accuracy: 0.8182 - AUC: 0.9265 - val_loss: 0.1898 - val_accuracy: 0.9286 - val_AUC: 0.9646
# Epoch 2/30
# 220/220 - 1s - loss: 0.1280 - accuracy: 0.9455 - AUC: 0.9919 - val_loss: 0.1163 - val_accuracy: 0.9643 - val_AUC: 0.9891
# Epoch 3/30
# 220/220 - 1s - loss: 0.0656 - accuracy: 0.9727 - AUC: 0.9984 - val_loss: 0.0574 - val_accuracy: 0.9643 - val_AUC: 0.9973
# Epoch 4/30
# 220/220 - 1s - loss: 0.0433 - accuracy: 0.9818 - AUC: 0.9991 - val_loss: 0.0438 - val_accuracy: 0.9821 - val_AUC: 1.0000
# Epoch 5/30
# 220/220 - 1s - loss: 0.0263 - accuracy: 0.9909 - AUC: 0.9997 - val_loss: 0.0390 - val_accuracy: 0.9643 - val_AUC: 1.0000
# Epoch 6/30
# 220/220 - 1s - loss: 0.0181 - accuracy: 0.9955 - AUC: 1.0000 - val_loss: 0.0250 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 7/30
# 220/220 - 1s - loss: 0.0079 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0192 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 8/30
# 220/220 - 1s - loss: 0.0070 - accuracy: 0.9955 - AUC: 1.0000 - val_loss: 0.0069 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 9/30
# 220/220 - 1s - loss: 0.0086 - accuracy: 0.9955 - AUC: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 10/30
# 220/220 - 1s - loss: 0.0105 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 11/30
# 220/220 - 1s - loss: 0.0049 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 12/30
# 220/220 - 1s - loss: 0.0023 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 13/30
# 220/220 - 1s - loss: 0.0021 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 14/30
# 220/220 - 1s - loss: 0.0015 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 15/30
# 220/220 - 1s - loss: 9.4668e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 8.6400e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 16/30
# 220/220 - 1s - loss: 6.0128e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 7.8356e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 17/30
# 220/220 - 1s - loss: 5.5212e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 6.4817e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 18/30
# 220/220 - 1s - loss: 4.7100e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 4.9512e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 19/30
# 220/220 - 2s - loss: 3.3867e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 4.1119e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 20/30
# 220/220 - 1s - loss: 2.8714e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 3.4070e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 21/30
# 220/220 - 1s - loss: 2.2985e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 2.9123e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 22/30
# 220/220 - 1s - loss: 1.8309e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 2.9661e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 23/30
# 220/220 - 1s - loss: 1.6477e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 2.5504e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 24/30
# 220/220 - 1s - loss: 1.5075e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 2.1464e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 25/30
# 220/220 - 1s - loss: 1.2779e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 1.8932e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 26/30
# 220/220 - 1s - loss: 1.2114e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 1.6991e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 27/30
# 220/220 - 1s - loss: 1.1124e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 1.5759e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 28/30
# 220/220 - 1s - loss: 1.0501e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 1.4750e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 29/30
# 220/220 - 1s - loss: 9.4639e-05 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 1.4110e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 30/30
# 220/220 - 1s - loss: 9.0248e-05 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 1.3089e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# In the fold 0: acc 1.0, roc 0.9999999999999999
# run fold:1
# Train on 220 samples, validate on 56 samples
# Epoch 1/30
# 220/220 - 25s - loss: 0.4507 - accuracy: 0.8091 - AUC: 0.9061 - val_loss: 0.1686 - val_accuracy: 0.9464 - val_AUC: 0.9933
# Epoch 2/30
# 220/220 - 1s - loss: 0.1564 - accuracy: 0.9364 - AUC: 0.9929 - val_loss: 0.1466 - val_accuracy: 0.9464 - val_AUC: 0.9826
# Epoch 3/30
# 220/220 - 1s - loss: 0.1009 - accuracy: 0.9636 - AUC: 0.9939 - val_loss: 0.1191 - val_accuracy: 0.9464 - val_AUC: 0.9920
# Epoch 4/30
# 220/220 - 1s - loss: 0.0504 - accuracy: 0.9864 - AUC: 0.9976 - val_loss: 0.0945 - val_accuracy: 0.9643 - val_AUC: 0.9973
# Epoch 5/30
# 220/220 - 1s - loss: 0.0288 - accuracy: 0.9955 - AUC: 0.9996 - val_loss: 0.0374 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 6/30
# 220/220 - 1s - loss: 0.0171 - accuracy: 0.9955 - AUC: 1.0000 - val_loss: 0.0111 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 7/30
# 220/220 - 1s - loss: 0.0057 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0125 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 8/30
# 220/220 - 1s - loss: 0.0047 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0133 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 9/30
# 220/220 - 1s - loss: 0.0054 - accuracy: 0.9955 - AUC: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 10/30
# 220/220 - 1s - loss: 0.0036 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 11/30
# 220/220 - 1s - loss: 0.0042 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 12/30
# 220/220 - 1s - loss: 0.0024 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 13/30
# 220/220 - 1s - loss: 0.0012 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 14/30
# 220/220 - 1s - loss: 8.5723e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 9.6929e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 15/30
# 220/220 - 1s - loss: 7.3227e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 7.9419e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 16/30
# 220/220 - 1s - loss: 5.5327e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 5.3174e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 17/30
# 220/220 - 1s - loss: 4.1012e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 4.1736e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 18/30
# 220/220 - 1s - loss: 3.3849e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 3.4205e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 19/30
# 220/220 - 1s - loss: 3.0621e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 2.8072e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 20/30
# 220/220 - 1s - loss: 2.4452e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 2.4780e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 21/30
# 220/220 - 1s - loss: 2.0807e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 2.3806e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 22/30
# 220/220 - 1s - loss: 1.8729e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 2.1576e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 23/30
# 220/220 - 1s - loss: 1.6491e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 1.9705e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 24/30
# 220/220 - 1s - loss: 1.4958e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 1.8428e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 25/30
# 220/220 - 1s - loss: 1.3825e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 1.7701e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 26/30
# 220/220 - 1s - loss: 1.3028e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 1.6399e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 27/30
# 220/220 - 1s - loss: 1.2177e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 1.5716e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 28/30
# 220/220 - 1s - loss: 1.1466e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 1.4500e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 29/30
# 220/220 - 1s - loss: 1.0633e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 1.3704e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 30/30
# 220/220 - 1s - loss: 9.8893e-05 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 1.3163e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# In the fold 1: acc 1.0, roc 1.0
# run fold:2
# Train on 220 samples, validate on 56 samples
# Epoch 1/30
# 220/220 - 24s - loss: 0.4238 - accuracy: 0.8091 - AUC: 0.9138 - val_loss: 0.1712 - val_accuracy: 0.9286 - val_AUC: 0.9875
# Epoch 2/30
# 220/220 - 1s - loss: 0.1569 - accuracy: 0.9364 - AUC: 0.9887 - val_loss: 0.1219 - val_accuracy: 0.9821 - val_AUC: 0.9822
# Epoch 3/30
# 220/220 - 1s - loss: 0.0917 - accuracy: 0.9636 - AUC: 0.9949 - val_loss: 0.0762 - val_accuracy: 0.9821 - val_AUC: 0.9934
# Epoch 4/30
# 220/220 - 1s - loss: 0.0436 - accuracy: 0.9864 - AUC: 0.9992 - val_loss: 0.0564 - val_accuracy: 0.9821 - val_AUC: 0.9960
# Epoch 5/30
# 220/220 - 1s - loss: 0.0263 - accuracy: 0.9955 - AUC: 0.9998 - val_loss: 0.0345 - val_accuracy: 0.9821 - val_AUC: 1.0000
# Epoch 6/30
# 220/220 - 1s - loss: 0.0160 - accuracy: 0.9955 - AUC: 1.0000 - val_loss: 0.0156 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 7/30
# 220/220 - 1s - loss: 0.0084 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 8/30
# 220/220 - 1s - loss: 0.0045 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0056 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 9/30
# 220/220 - 1s - loss: 0.0026 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 10/30
# 220/220 - 1s - loss: 0.0015 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 11/30
# 220/220 - 1s - loss: 0.0012 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 12/30
# 220/220 - 1s - loss: 9.3667e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 7.7141e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 13/30
# 220/220 - 1s - loss: 5.8102e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 14/30
# 220/220 - 1s - loss: 4.0320e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 15/30
# 220/220 - 1s - loss: 3.7001e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 7.1860e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 16/30
# 220/220 - 1s - loss: 3.1282e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 5.3381e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 17/30
# 220/220 - 1s - loss: 2.6246e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 4.1135e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 18/30
# 220/220 - 1s - loss: 2.1441e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 3.5016e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 19/30
# 220/220 - 1s - loss: 1.7975e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 3.1963e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 20/30
# 220/220 - 1s - loss: 1.6691e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 2.9026e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 21/30
# 220/220 - 1s - loss: 1.4502e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 2.6041e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 22/30
# 220/220 - 1s - loss: 1.3985e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 2.4157e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 23/30
# 220/220 - 1s - loss: 1.3183e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 2.7245e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 24/30
# 220/220 - 1s - loss: 1.3421e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 2.4524e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 25/30
# 220/220 - 1s - loss: 1.1657e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 1.7506e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 26/30
# 220/220 - 1s - loss: 1.0082e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 1.4678e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 27/30
# 220/220 - 1s - loss: 9.3403e-05 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 1.3292e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 28/30
# 220/220 - 1s - loss: 8.7700e-05 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 1.2399e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 29/30
# 220/220 - 1s - loss: 8.4216e-05 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 1.0088e-04 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 30/30
# 220/220 - 1s - loss: 7.9787e-05 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 9.3077e-05 - val_accuracy: 1.0000 - val_AUC: 1.0000
# In the fold 2: acc 1.0, roc 1.0
# run fold:3
# Train on 220 samples, validate on 56 samples
# Epoch 1/30
# 220/220 - 25s - loss: 0.4195 - accuracy: 0.8000 - AUC: 0.9177 - val_loss: 0.1906 - val_accuracy: 0.9107 - val_AUC: 0.9861
# Epoch 2/30
# 220/220 - 1s - loss: 0.1603 - accuracy: 0.9273 - AUC: 0.9895 - val_loss: 0.0993 - val_accuracy: 0.9643 - val_AUC: 0.9958
# Epoch 3/30
# 220/220 - 1s - loss: 0.0886 - accuracy: 0.9818 - AUC: 0.9970 - val_loss: 0.0681 - val_accuracy: 0.9821 - val_AUC: 0.9972
# Epoch 4/30
# 220/220 - 1s - loss: 0.0444 - accuracy: 0.9909 - AUC: 0.9995 - val_loss: 0.0404 - val_accuracy: 0.9821 - val_AUC: 1.0000
# Epoch 5/30
# 220/220 - 1s - loss: 0.0214 - accuracy: 0.9955 - AUC: 1.0000 - val_loss: 0.0242 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 6/30
# 220/220 - 1s - loss: 0.0125 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0150 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 7/30
# 220/220 - 1s - loss: 0.0075 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0093 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 8/30
# 220/220 - 1s - loss: 0.0047 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0213 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 9/30
# 220/220 - 1s - loss: 0.0018 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 10/30
# 220/220 - 1s - loss: 0.0036 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0245 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 11/30
# 220/220 - 1s - loss: 0.0011 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0528 - val_accuracy: 0.9643 - val_AUC: 1.0000
# Epoch 12/30
# 220/220 - 1s - loss: 8.0874e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0164 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 13/30
# 220/220 - 1s - loss: 5.1957e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0147 - val_accuracy: 1.0000 - val_AUC: 1.0000
# Epoch 14/30
# 220/220 - 1s - loss: 4.2175e-04 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.0125 - val_accuracy: 1.0000 - val_AUC: 1.0000
# In the fold 3: acc 1.0, roc 0.9999999999999999
# run fold:4
# Train on 220 samples, validate on 56 samples
# Epoch 1/30
# 220/220 - 25s - loss: 0.4813 - accuracy: 0.7818 - AUC: 0.8646 - val_loss: 0.2371 - val_accuracy: 0.9107 - val_AUC: 0.9542
# Epoch 2/30
# 220/220 - 1s - loss: 0.1716 - accuracy: 0.9318 - AUC: 0.9931 - val_loss: 0.1547 - val_accuracy: 0.9464 - val_AUC: 0.9792
# Epoch 3/30
# 220/220 - 1s - loss: 0.0857 - accuracy: 0.9636 - AUC: 0.9984 - val_loss: 0.1461 - val_accuracy: 0.9643 - val_AUC: 0.9806
# Epoch 4/30
# 220/220 - 1s - loss: 0.0452 - accuracy: 0.9955 - AUC: 1.0000 - val_loss: 0.1847 - val_accuracy: 0.9643 - val_AUC: 0.9764
# Epoch 5/30
# 220/220 - 1s - loss: 0.0257 - accuracy: 0.9909 - AUC: 1.0000 - val_loss: 0.2167 - val_accuracy: 0.9464 - val_AUC: 0.9611
# Epoch 6/30
# 220/220 - 1s - loss: 0.0103 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.1664 - val_accuracy: 0.9464 - val_AUC: 0.9861
# Epoch 7/30
# 220/220 - 1s - loss: 0.0128 - accuracy: 0.9955 - AUC: 1.0000 - val_loss: 0.2297 - val_accuracy: 0.9643 - val_AUC: 0.9694
# Epoch 8/30
# 220/220 - 1s - loss: 0.0085 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.2487 - val_accuracy: 0.9643 - val_AUC: 0.9708
# In the fold 4: acc 0.9855072463768116, roc 0.9914529914529914
